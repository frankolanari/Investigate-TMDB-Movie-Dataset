# %% [markdown]
# # Project : Investigate a Movie Dataset (TMDB Movie Dataset)
# ## by Frank Emmanuel Azibolanari
# ## Introduction
#
# I have Chosen the TDMB dataset for this project and this dataset contains information about over 10,000 movies collected from The Movie Database (TMDb) such as casts,production companies, the budget, the profit,ratings, the genres, etc.
# I have made a fictional scenerio that will guide the trajectory of my analysis; I have been employeed as a data analyst by a Hollywood Agency. The focus of my analysis would be to help my employeer make databased decisions to get the best cast, directors and production studios that they can work with and recommend for clients.
# I would go through data wranggling phase, then data exploration phase  to in order to answer some questions and then conclusion in accordance with the project rubrics.
# During the course of this analysis I shall answer a few questions that my fictional employeer have asked of me.

# %% [markdown]
# ##### Importing the python modules required
# To begin, Lets install the neccessary python modules required for our analysis.. which are pandas, numpy, matplotlib, and seaborn.

# %%
#Importing all the modules required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

##setting the default theme for seaborn
sns.set()
##Removing Warnings 
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Taking a Look at our data
# Lets take a look at the dataset. In order to do that, we have to load in the dataset that is in csv file into the jupyter notebook and take a look at what is contained in it.

# %%
#importing the dataset into the Jupyter notebook and storing it in a dataframe I called 'df_tmdb'
df_tmdb= pd.read_csv('tmdb-movies.csv')
#Checking the first 5 rows in the data set
df_tmdb.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# #### COMMENTS ON OUR DATASET
# After taking a glimpse on our dataset, we can see that there are the column names are well defined and easy to understand as they are plain and straightfoward with no abbreviations, or coverted reprensentation with the exception of the last two columns "budget_adj" and "revenue_adj", of which I'll be dropping both anyways.
# It is important to note that no currency was assigned to the 'budget' and 'revenue' columns, but I would assume they are in United States Dollars(USD) based on my discretion.
# I will also assume that the vote average is over 10 based on my discretion, although it was'nt stated as such. my major reason for this because I noticed an 'IMDB id' column, so am guessing the vote average is from IMDB which use a 10 point rating system or atleast that's how most ratings are in the industry.

# %% [markdown]
# #### QUESTIONS TO ANSWER FROM OUR DATA
# My fictional employer has informed me that he is interested in two major parameters of success; movies with profit above the all time average or ratings beyond 6.5/10. So my I'll conduct my analysis with that in mind.
# Lets dive deeper into our data by answering some basic questions that would gives us the parameter to decide which movies to regard as successful in accor refer to as successful movies and  other question  that will give us some insights about our data and help use draw informed conclusions.
#
# **Basic Questions**
#      <nl>
#      A. What is the average budget of all the movies?
#      B. What is the average Profit of all the movies?
#      C. What is the average rating of all the movies?
#      </nl>
#
# **Research Questions**
# * Is there a corelation between profit and ratings?
# * what is the trend in budget and profit of sucessful movies across the  years?
# * what are the top 20 movies of all time?
# * Who directed the top 10 most rated movies of all time?
# * Which genres are most produced?
# * which directors made the most successful Movies?
# * which actors were casted the most in successful movies?
# * Which movie had the highest budget and lowest budget of all the successful movies?
# * Which movie had the highest budget and lowest profit of all the successful movies?
#
# **Research-Summary Questions**
# 1. Which movie had the highest budget and lowest budget of all the successful movies?
# 2. Which Movie made the highest profit and lowest profit of all the successful movies?
# 3. Which actors that appeared the most in successful movies in the last 15 years
# 4. Which actors that appeared the most in successful movies in the last 5 years?
# 4. who are the top 15 directors that made the most number of successful movies in the last decade?
# 5. what are the top 15 studios that made the most number of successful movies in the last decade (2010 - 2015)

# %% [markdown]
# #### AREA OF INTEREST
# In order to successfully to accomplish my objectives, I would be working with some certain columns that would be crucial for my analysis. The main columns that are of interest are; budget, revenue, original_title, cast, director, genres, runtime, production_companies,release_date, and vote_average.

# %% [markdown]
# # DATA WRANGLING
# <hr>
# At this phase, we clean and tidy up our dataset for easy access and analysis.
# But the first is to assess and check our data before we clean and make adjustments.

# %% [markdown]
# ### Assessing  and Cleaning the Data
# Let's observe our data properties, drop irrelevant columns that we would not use for our analysis and check for things that would require cleaning such as duplicates, null_values, zero values, inappropriate datatypes and make adjustments.
# I have decided to check and clean for errors as we spot them as we go.

# %% [markdown]
# **Details Of The Data Properties**

# %%
#Checking the general properties of the data
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# We can see there are 10866 records and a total of 21 columns in this dataset. The dataset consist of 4 float columns, 6 integer columns, and 11 object columns.

# %% [markdown]
# **Dropping The Irrelevant Columns**
# Before we proceed looking for nulls,duplicates,zero values, etc; Let's drop the irrelevant columns. These rows would be needed in this particular analysis... so, I am regarding them as irrelevant and dropping them.

# %%
# Creating a list to store the the columns to be dropped.
irrelevant_col = ['id', 'tagline', 'homepage', 'overview', 'keywords', 'budget_adj', 'vote_count', 'revenue_adj']
df_tmdb = df_tmdb.drop(irrelevant_col, axis = 1)

# %%
#Let's confirm if the irrelevant columns has been removed
df_tmdb.head(1)
# Out:
#      imdb_id  popularity     budget     revenue  original_title  \
# 0  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15
#
#    vote_average  release_year
# 0           6.5          2015

# %% [markdown]
# Great! we have dropped all irrelevant columns, notice how those columns are no longer in our dataframe. Now we are left with the columns needed for our our anlysis. I choose to leave a few other columns, but they would'nt be a bother.

# %% [markdown]
# **Checking for null values**

# %%
#checking for null values
df_tmdb.isnull().sum()
# Out:
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# director                  44
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_average               0
# release_year               0
# dtype: int64

# %% [markdown]
# Wow, that's quite a number of null values, I wasn't expecting this much.
# However, after thoughful consideration, I think it be best to drop those null values, I doubt they cause any serious impact to our analysis.

# %% [markdown]
# **Dropping Null Values**

# %%
#Dropping null_values
df_tmdb = df_tmdb.dropna()

# %%
##Confirming if the null values have been dropped
df_tmdb.isnull().sum()
# Out:
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_average            0
# release_year            0
# dtype: int64

# %% [markdown]
# **Checking for Duplicates**
# Let's check if there are any duplicates in our dataframe.

# %%
#checking for duplicates
duplicates = df_tmdb[df_tmdb.duplicated()]
duplicates
# Out:
#         imdb_id  popularity    budget  revenue original_title  \
# 2090  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast          director  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...  Dwight H. Little
#
#       runtime                                       genres  \
# 2090       92  Crime|Drama|Action|Thriller|Science Fiction
#
#         production_companies release_date  vote_average  release_year
# 2090  Namco|Light Song Films      3/20/10           5.0          2010

# %% [markdown]
# Wow! I am impressed that is just one duplicate in this dataset, applauses to kaggle.
# Now lets proceed to remove this duplicate from our dataframe.

# %% [markdown]
# **Removing Duplicates**

# %%
#Removing Duplicates
df_tmdb.drop_duplicates(inplace=True)

# %%
#confirming the duplicates have been removed
df_tmdb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Changing release_date to Datetime format**
# The release_date is in a string format represented as Object, however we want this to be in datetime format.

# %%
#Changing the 'realease_date' colunmn from string to datetime datatype. 
df_tmdb['release_date'] = pd.to_datetime(df_tmdb['release_date'])
#Confirming the change to datetime format
df_tmdb['release_date'].head(0)
# Out:
# Series([], Name: release_date, dtype: datetime64[ns])

# %% [markdown]
# Great! we can see the release_date column is now in datetime format.

# %% [markdown]
# **Removing Zero Values (0)**
# Now, let's remove zero values from the budget,revenue,runtime, and popularity columns if any. We do movies with zero values in those selected columns. Obviously, we want movies that has a budget,revenue,runtime and some level of popularity no matter how little.

# %%
#Removing any Zero (0)

#Creating a list holding columns I wish to remove zero values from.
zero_values = ['budget', 'revenue', 'popularity', 'runtime']

#converting all zero (0) values to null values using Numpy
df_tmdb[zero_values] = df_tmdb[zero_values].replace(0, np.NAN)

#Droping the the just converted null values from our list
df_tmdb.dropna(subset = zero_values, inplace = True)

# %%
## Confirming Changes
df_tmdb.shape
# Out:
# (3805, 13)

# %% [markdown]
# Whoa! As we can see, we now have a total of 3805 records in contrast to the 10866 records we had before cleaning. I totally wasn't expecting such a drastic reduction in the volume of records I'll be working with. But rest assured, we're working with just what we need.

# %% [markdown]
# #  Exploratory Data Analysis (EDA)
# <hr>

# %% [markdown]
# Our data is cleaned and ready for EDA. At this phase, we shall dig deeper into our data to answer the set questions.
# We shall start with the Basic Questions...

# %% [markdown]
# ## Answering The Basic Questions
# <hr>

# %% [markdown]
# Our fictional employer defines successful movies as movies with profits or ratings beyond the mediocre. This translates to movies with profit greater that the average profit or ratings greater than 6.5/10, in this dataset.
# The basic questions gives a parameter to determine which movies should be regarded as successful movies as they would reveal the average.

# %% [markdown]
# > #### Function 1: Get the Average of Column of Interest.
# Inorder to make our code less ambigous, Let's define a function that returns the  average of  a particular column and also create another to make a box plot of the column. This would make answering the our basic questions quite easy and done with simpler code. I use functions anywhere I can.

# %%
#Defining a function to calculate the average of the column of interest.
def cal_avg(column):
    return df_tmdb[column].mean()

# %% [markdown]
# <hr>

# %% [markdown]
# ### Basic Question A: What is the average budget of all the movies?

# %%
#Using the cal_avg function to find the average budget
cal_avg('budget')
# Out:
# 37607996.559526935

# %% [markdown]
# The boxplot gives us an overview of the distribution of the budget of movies across the dataset.
# By using the cal_avg, we get a precise answer to the question, the average budget of all the movies in this dataset is approximately 37.6 million USD.

# %% [markdown]
# ### Basic Question B: What is the average profit of all the movies?
# Let's derive profit from the budget and revenue first. To do this I'll deduct the budget from the revenue and store it in a new columm to hold the profit.

# %%
#Creating a column for Profit
df_tmdb['net_profit'] = df_tmdb['revenue'] - df_tmdb['budget']
#checking if the opperation was a success to see if the new column appears in the dataframe
df_tmdb.head(1)
# Out:
#      imdb_id  popularity       budget       revenue  original_title  \
# 0  tt0369610   32.985763  150000000.0  1.513529e+09  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#    runtime                                     genres  \
# 0    124.0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
#
#    vote_average  release_year    net_profit
# 0           6.5          2015  1.363529e+09

# %% [markdown]
# There it is, in the extreme right. Now that we have successfully created the net profit column, we can proceed to answer the prevailing question. Which is, what is the average profit?

# %%
#Using the cal_avg to calculate the average profit
cal_avg('net_profit')
# Out:
# 71365395.43206307

# %% [markdown]
# The box plot gives us an overview of the distribution of the profit made by movies across the dataset.
# By using the cal_avg, we get a precise answer to the question, The average profit made by movies is approximately 71.4 million USD.

# %% [markdown]
# #### Basic Question C: What is the average runtime of all the movies?

# %%
#Using our boxplot_col function to plot the distribution of runtime of movies
plt.figure(figsize=(5,3), dpi = 100)
df_tmdb.boxplot('runtime', vert=False, sym = '')
plt.title('Movie Runtime Distribution');

# %%
cal_avg('runtime')
# Out:
# 109.35111695137977

# %% [markdown]
# The box plot gives us an overview of the distribution of the runtime of movies across the dataset. We can see that the median value is somewhere close 110 thats the middle point between 100 and 120, but not quite at 110.
# By using the cal_avg, we get a precise answer to the question, the average runtime of movies is approximately 109 minutes.

# %% [markdown]
# #### Basic Question D: What is the Average rating.
# The column representing the ratings is the 'vote_average' column. so that's the column we would apply to the cal_avg function.

# %%
cal_avg('vote_average')
# Out:
# 6.170565045992117

# %% [markdown]
# okay, so the average rating can be round up to 6.2. The thing is 6.2/10 seems a little mediocre to my fictional boss, so we would be using a higher slightly higher rating of 6.5/10. Now we have the parameters for deciding which movies are to be considered as successful.

# %% [markdown]
# ## Answering The Research Questions
# <hr>
# I think it would be fun to explore and gain insights about our dataset, some of which could prove useful to my fictional boss in some way.

# %% [markdown]
# ### Research Question 1: Is there a corelation between profit and ratings?
# Let's see if there might be a corelation between profit and ratings by observing

# %%
# Checking the relationship between profits vs Ratings  using scatterplot
fig = plt.figure(figsize=(10,5))
ax = sns.scatterplot(x = 'vote_average', y = 'net_profit', data = df_tmdb);
plt.xlabel('Ratings', fontsize =14)
plt.ylabel('Profit', fontsize=14)
plt.title('Profit and Ratings Correlation Plot', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Profit and Ratings Correlation Plot')

# %% [markdown]
# From the plot we can observe that as the ratings increase so does the profit.There might be a correlation between ratings and profits. We can see how as the rattings increase there seem to also some increase in profit. However, as expected there are expections. That said, this plot shows a partern, it doesn't mean neccessarily mean that ratings is the determinant of of profit or vice versa.

# %% [markdown]
# ###  Research Question 2: What is the trend of profit of movies across all the years?
# This plot should give us an overview on  how profit voulme is distributed across the years.

# %%
total_profit_per_year = df_tmdb.groupby('release_year')['net_profit'].sum()
total_budget_per_year = df_tmdb.groupby('release_year')['budget'].sum()
#defining the plot dimensions
plt.figure(figsize=(15,7), dpi = 135)
#labeling the x-axis
plt.xlabel('Release Year', fontsize = 14)
#labeling the y-axis
plt.ylabel('Amount in USD', fontsize = 14)
#Giving the plot a title
plt.title('Total Profit and Total Budget per Year', fontsize = 20)

#plotting the total profit and total budget per year
line1, = plt.plot(total_profit_per_year, label = 'Total Profits')
line2, = plt.plot(total_budget_per_year, label = 'Total Budget')
legend = plt.legend(loc='upper left', fontsize =14)
plt.show()

# %% [markdown]
# From the plot it shows gradual progression in both the budget and profits made by movies accross the years. We can observe that in the earlier years the growth was rather slow, we can see how long the budget stay near stagnant for more than a decade from the 60s with spiking profit levels. However, sometime around the mid 70s we observed that there has been a breakthrough out of the seemingly stangnat budget, since then there has been consistent growth in the budget over the years, until much recently, the budget seemed to dwindle a little.
# We can also see that there has been an exponential growth in profit in the last 3 decades. Also notice how the profit margin increases over time, and we observed that despite the dwindling of the budget, the profit keeps going up resulting in a larger profit margin. I see the evolution of the movie industry!

# %% [markdown]
# <hr>

# %% [markdown]
# > **CREATING A NEW DATAFRAME FOR SUCCESSFULL MOVIES**
# At this point I think it would be nice to filter our data based on ratings,profit or the marging of both criteria which we regard as the successful movies. This would make my code simpler and cleaner later on, because the following questions would requires such filtering.
# The metric for deciding which movies count as sucessful, they have to exceed the average. These successful movies must have a net profit greater than the average of 71.4 million USD or with a vote_average greater than 6.5.

# %%
#Creating a dataframe to hold movies with average above 71.4 million USD or with ratings above 6.5
#Filter1: This filters based on ratings only
toprated= df_tmdb.loc[(df_tmdb['vote_average'] > 6.5)]
#Filter2: This filters based on profit only
topprofit = df_tmdb.loc[(df_tmdb['net_profit'] > 71400000)] 
#Filter3: This filters based on  both profit and ratings using an 'OR' bool.
topmovies = df_tmdb.loc[(df_tmdb['net_profit'] > 71400000)|(df_tmdb['vote_average'] > 6.5)]

# %%
#Checking if the filter operation worked as expected.
#checking Filter1
print('Top rated:',toprated.shape)
#checking Filter2
print('Top Profit:', topprofit.shape)
#checking Filter3
print('All Successful Movies:', topmovies.shape)
# Out:
# Top rated: (1229, 14)
# Top Profit: (1061, 14)
# All Successful Movies: (1844, 14)

# %% [markdown]
# Wow! We can see that the number of movies by filter which shows that our filter does work as intended.
# So there are a total of 1229 movies that have ratings above average of 6.5/10 which I named toprated, a total of 1061 movies with profits above the 71.4 million USD average. The total number of movies that meet either or both of those criteria are a sum of 1844. So there are 1844 movies that my fictional boss would consider as successful movies, which would be the main dataframe we would be working with.
# <hr>

# %% [markdown]
# > #### Function 2: Get the Highest Value in a Column From The Newly created DataFrames.
# The fuction fetches the top values in a selected ***column*** from the top_by_profit and top_by_rating dataframes. The funtion lets me determine the how many results we want, represented as top_no. For example, if we wanted the top 10, we put 10 in the top_no space.

# %%
#DEfining the functions that fetches the top values in a column
#For fetching top values from top profit dataframe
def top_by_profit(top_no, column):
     return topprofit.nlargest(top_no, column)

#For fetching top values from top rated dateframe
def top_by_ratings(top_no, column):
     return toprated.nlargest(top_no, column)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Research Question 3: What are the Top 20 movies by Profit?
# Let's create a plot that shows a ranking of the top movies, using matplotlib.

# %%
#Plotting the top 20 movies by profit
#creating a small dataframe to hold the top 20 movies by profit derived using the top_by_profit function.
top_20_rated = top_by_profit(20,'net_profit')
#defining the dimensions of the plot
fig = plt.figure(figsize=(15,7), dpi=135)
#Titling the plot
plt.title('Top Movies By Profit Of All Time', fontsize=20)
#creating the plot using seaborn
ax = sns.barplot(x='net_profit', y='original_title', data=top_20_rated)
#removing the xticks labels because they didn't seem asthetically pleasing
ax.set_ylabel('')    
ax.set_xlabel('')
#labeling the x and y axis
plt.xlabel('Net Profit', fontsize = 14)
plt.ylabel('Movie Name', fontsize = 14)
#Displaying the plot
plt.show()

# %% [markdown]
# Whoa! The Avatar tops the charts unparrarelled. Truely and amazing movie making a profit exceeding a whooping 2.5 Billion USD.
# This plots,shows the other the  movies that makes top 20 movies by profit. We can see the movies on the y axis and the profit in USD on the x axis. Followed by 'Avatar', is 'Star Wars: The Force Awakens' making close to 2 Billion USD, then the classics 'Titanic' making a over 1.5 Billion USD etc..

# %% [markdown]
# ### Research Question 4: Who Directed the Top 10 most rated Rated Movies of all time?
# Let's see the most rated movies and their directors. we'll a table that shows the list of the 10 most rated movies of all time and the people who directed them.

# %%
#creating a small dataframe to hold the top 10 movies by ratings.
top_rated_movies = top_by_ratings(10,'vote_average')
#making a list to hold the irrelevant columns
droprated =['budget','imdb_id','popularity','production_companies','budget','revenue','cast','runtime','release_date','net_profit']
#dropping irrelevant columns in this dataframe
top_rated_movies = top_rated_movies.drop(droprated, axis=1)
#Displaying the results
top_rated_movies
# Out:
#                  original_title              director  \
# 4178   The Shawshank Redemption        Frank Darabont
# 7948          Stop Making Sense        Jonathan Demme
# 7269              The Godfather  Francis Ford Coppola
# 650                    Whiplash       Damien Chazelle
# 2409                 Fight Club         David Fincher
# 2875            The Dark Knight     Christopher Nolan
# 4177               Pulp Fiction     Quentin Tarantino
# 4179               Forrest Gump       Robert Zemeckis
# 9758     The Godfather: Part II  Francis Ford Coppola
# 10222          Schindler's List      Steven Spielberg
#
#                             genres  vote_average  release_year
# 4178                   Drama|Crime           8.4          1994
# 7948             Documentary|Music           8.4          1984
# 7269                   Drama|Crime           8.3          1972
# 650                    Drama|Music           8.2          2014
# ...

# %% [markdown]
# We can now see the most top 10 most rated movies and as well as the directors, the genre, and release year of these movies.

# %% [markdown]
# <hr>

# %% [markdown]
# > #### Function 3 : Seperate and fetch the value count of  individual values in a colum
# In order to easily answer the subsequent question efficiently with less ambiguity,  we'll define a function that seperate and  fetch out strings in a column seperated by vertical line ( | ). The function would allow me choose a ***column*** of interest from a selected ***dataframe*** to work on and also allow me choose the ***number*** of result I want. I made it flexible, cause I might need to use this function later on.

# %%
#Defining the function to seperate and fetch the  top value counts... 
def fetch_vcount(dataframe,column, number):
    #This seperates the values by the '|' seprator
    col_values = dataframe[column].str.cat(sep = '|')
    #storing them in a pandas series
    col_values = pd.Series(col_values.split('|'))
    #getting the value counts 
    v_counter = col_values.value_counts(ascending = False)
    #determing the how many of the highest value counts to return
    v_count = v_counter.head(number)
    return v_count

# %% [markdown]
# <hr>

# %% [markdown]
# ### Research Question 5: What are the Top 10 Genres of Successful movies produced?
# We want to see a plot that shows a ranking of movie genres based the most produced. We would be using matplotlib to plot it.

# %%
#This will variable will store the return value from the fetch_vcount function
top_genres= fetch_vcount(topmovies,'genres',10)
#shwoing top 5 values
top_genres
# Out:
# Drama              911
# Comedy             583
# Action             499
# Thriller           493
# Adventure          417
# Romance            321
# Crime              307
# Family             245
# Science Fiction    237
# Fantasy            214
# dtype: int64

# %%
top_genres.sort_values(ascending = True, inplace = True)

#plotting the Most Produced Genres
ax = top_genres.plot.barh(fontsize = 15)
#Setting a title
plt.title('Most produced Genres', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies', fontsize = '14')
#labelling the y axis
plt.ylabel('Movie Genres', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# Wow! What a dramatic turnout of events, pun intended; The drama genre takes the lead in the charts. To answer our question, the **top 10 can be seen rank in the plot as follows; Drama, comedy, action,  thriller, adventure, romance, crime, family, science fiction, and fantasy.**
# This plot shows the genres that dominates in the movie production industry.

# %% [markdown]
# ### Research Question 6: which directors made the most successful Movies?
# Let's see the most exprienced directors that made the most successfull. So all the movies well be counting here, are their movies. Let's take the top 15.

# %%
#This will variable will store the return value from the fetch_vcount function
most_xp_dir = fetch_vcount(topmovies,'director',15)
#Displaying results
most_xp_dir
# Out:
# Steven Spielberg     24
# Martin Scorsese      16
# Clint Eastwood       15
# Tim Burton           14
# Robert Zemeckis      13
# Ridley Scott         12
# Ron Howard           11
# Woody Allen          11
# Joel Coen            10
# Peter Jackson        10
# Quentin Tarantino    10
# David Fincher        10
# Steven Soderbergh     9
# Stanley Kubrick       8
# Joel Schumacher       8
# dtype: int64

# %%
#plotting the Most Produced Genres
ax = most_xp_dir.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top Directors Of All Time', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Directed', fontsize = '14')
#labelling the y axis
plt.ylabel('Directors', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# From the plot we can see the rankings of directors based on the number of successfull movies they directed. only successful movies they directed, that is movies that scored a rating above 6.5 or with a profit over 71.4 million USD. These are truly exceptional directors, but Steve Spielberg takes the lead by a significant margin, driecting over 24 successful movies amazing!

# %% [markdown]
# ### Research Question 7: which actors were casted the most in successful movies?

# %% [markdown]
# Let's see the actors that appeared the most in successful movies. I'll make a plot to visualize a ranking of the top 20 actors that appeared the most in successful movies of all time

# %%
#This will variable will store the return value from the fetch_vcount function
most_xp_cast = fetch_vcount(topmovies,'cast',20)
#displaying the value
most_xp_cast
# Out:
# Robert De Niro        32
# Tom Cruise            27
# Brad Pitt             26
# Tom Hanks             24
# Denzel Washington     22
# Sylvester Stallone    22
# Harrison Ford         22
# Johnny Depp           21
# Cameron Diaz          21
# Dustin Hoffman        21
# Matt Damon            20
# Samuel L. Jackson     20
# Morgan Freeman        20
# Adam Sandler          20
# Meryl Streep          20
# Robin Williams        19
# Jim Carrey            19
# Bruce Willis          19
# Al Pacino             18
# Eddie Murphy          18
# dtype: int64

# %%
#creating the plot
ax = most_xp_cast.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top Cast Of All Time', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Featuring', fontsize = '14')
#labelling the y axis
plt.ylabel('Actors/Actresses', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# Wow! we can see the household names in hollywood, these are hollywood legendary actors! Taking the the lead is ranking is Robert De Niro, featuting in a 32 successful movies, followed by Tom Cruise featuring in 27 movies, then Brad Pitt featuring in 26 movies, then Tom Hanks featuring in 24, movies, Then Denzel Washington feauting in 22 movies and a few others as seen in the plot. It's important to stress the fact that this ranking isn't based on the total number of movies these actors have been featured in, rather the number of movies they have featured in that made over 71.4 million USD or ratings above 6.5/10.

# %% [markdown]
# ###  Research Question 8: which Production Studios made the most successful Movies?
# Let's see the top studios that made the most successfull movies. Let's take the top 15. This will be visualized using matplotlib

# %%
#Listing a the top studios with precise detail of the number of successful movies produced
best_studios = fetch_vcount(topmovies,'production_companies',15)
best_studios
# Out:
# Universal Pictures                        183
# Warner Bros.                              182
# Paramount Pictures                        147
# Twentieth Century Fox Film Corporation    122
# Columbia Pictures                         102
# Walt Disney Pictures                       82
# New Line Cinema                            77
# Touchstone Pictures                        61
# Metro-Goldwyn-Mayer (MGM)                  55
# Columbia Pictures Corporation              54
# Relativity Media                           50
# DreamWorks SKG                             46
# Amblin Entertainment                       41
# Miramax Films                              39
# TriStar Pictures                           38
# dtype: int64

# %%
#creating the plot
ax = best_studios.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 15 Studios Of All Time', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Produced', fontsize = '14')
#labelling the y axis
plt.ylabel('Studios/Production Companies', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# Great! Now we can see the ranking clearly from the plot. There is a total of 15 studios, of which Universal Pictures takes the crown producing 183 successful movies, followed closely by the Warner Brothers,then Paramount Pictures,the 20th Century Fox and so on...

# %% [markdown]
# >##### Function 4 : Return Highest and Lowest Values in a Column
# Inorder to make our code less ambigous, Let's define a function that returns and concatenates the highest and lowest values in a column. This would make answering the first four basic questions quite easy and done with simpler code.

# %%
##Defining a function that calculates the highest and lowest value in a column
def Cal_MinMax(dataframe,column):
    #calculates  the highest value in the column of interest
    maxv = dataframe[column].idxmax()
    max_value = pd.DataFrame(topmovies.loc[maxv])
    
    #Calculates the lowest value in the column of interest
    minv = dataframe[column].idxmin()
    min_value = pd.DataFrame(topmovies.loc[minv])
    
    #Concatinating our max and min values
    concat_MinMax = pd.concat([max_value, min_value], axis = 1)
    
    return concat_MinMax

# %% [markdown]
# ____

# %% [markdown]
# ### Research Question 9 : Which movie had the highest budget and lowest budget of all the successful movies?
# Let's get find out what the minimum and maxium budget of these successful movies, this could be helpful during planning and decision making for my employer, he can also use this kind  of imformation to tell his clients what kind of budget to keep in mind etc...

# %%
#Now we can use the function we had defined earlier that returns the highest and lowest value in a column....
#In this case, we would be using the 'budget' column...
Cal_MinMax(topmovies,'budget')
# Out:
#                                                                    3375  \
# imdb_id                                                       tt1298650
# popularity                                                      4.95513
# budget                                                      380000000.0
# revenue                                                    1021683000.0
# original_title              Pirates of the Caribbean: On Stranger Tides
# cast                  Johnny Depp|Pen̩lope Cruz|Geoffrey Rush|Ian M...
# director                                                   Rob Marshall
# runtime                                                           136.0
# genres                                         Adventure|Action|Fantasy
# production_companies  Walt Disney Pictures|Jerry Bruckheimer Films|M...
# release_date                                        2011-05-11 00:00:00
# vote_average                                                        6.3
# ...

# %% [markdown]
# ### Research Question 10 : Which movie had the highest budget and lowest profit of all the successful movies?
# Let's get find out what the minimum and maxium budget of these successful movies, this could be helpful during planning and decision making for my employer, he can also use this kind  of imformation to tell his clients what to expect etc...

# %%
#Now we can use the function we had defined earlier that returns the highest and lowest value in a column....
#In this case, we would be using the 'budget' column...
Cal_MinMax(topmovies,'net_profit')
# Out:
#                                                                    1386  \
# imdb_id                                                       tt0499549
# popularity                                                     9.432768
# budget                                                      237000000.0
# revenue                                                    2781505847.0
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                  James Cameron
# runtime                                                           162.0
# genres                         Action|Adventure|Fantasy|Science Fiction
# production_companies  Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                        2009-12-10 00:00:00
# vote_average                                                        7.1
# ...

# %% [markdown]
# ____

# %% [markdown]
# > #### Creating a new dataframe for successful movies in the last decade, last 15 years, and the last 5 years.
# Inorder to easily answer the upcoming questions, let's create a dataframe to hold only successful movies based on period of release. we'll be focused on movies released in the last 15 years, last decade(10 years), and the last 5 years. This would the main focus of our analysis, as my objectives is to find recommendable directors, actors/actressess, and studios for the agency to work with, so we need people and brands that are ***could*** be still active and relevant in the industry currently

# %%
#First let's figure out which is the last year in the dataset.
topmovies['release_year'].max()
# Out:
# 2015

# %% [markdown]
# great! we can see the latest year inthis dataset is 2015. Now we proceed.

# %%
#Creating a dataframe to hold movies that were released in the last 15 years
last15yrs = topmovies[(topmovies['release_date'] >= '2000-01-01') & (topmovies['release_date'] <= '2015-12-31')]

#Creating a dataframe to hold movies that were released in the last 10 years
last10yrs = topmovies[(topmovies['release_date'] >= '2005-01-01') & (topmovies['release_date'] <= '2015-12-31')]

#Creating a dataframe to hold movies that were released in the last 10 years
last5yrs = topmovies[(topmovies['release_date'] >= '2010-01-01') & (topmovies['release_date'] <= '2015-12-31')]

# %% [markdown]
# <hr>

# %% [markdown]
# ### Summary Question 1: What is the average budget and Profit of successful movies in the 5 years?
# Let's see what the average budget of successful movies is. This can give us an idea of what kind of budget it takes on average to make a movie that we might expect to ***probably*** make profits of over 71 million USD or 6.5 ratings, and what kind of profit to ***possibly*** expect to make.

# %%
#calculating average budget of successful movies in the last 5 years
avgbudget = last5yrs['budget'].mean()
avgbudget
# Out:
# 62376169.0

# %%
#calculating average budget of successful movies in the last 5 years
avgprofit = last5yrs['net_profit'].mean()
avgprofit
# Out:
# 179863378.82524273

# %% [markdown]
# From the result we can see that it take an average of approximately 62 million USD in budget to produce a successful movie and an average profit of approximately 180 million USD in recent times (with the lastest 5 yrs). Notice how the average budget and profit have increased substantially in recent times, the average budget budget of the last decade is now almost twice of the average budget of all time(approx. 37 million USD), and the average profit is more than twice the average of all time(approx 71 million USD)!
# However, this is not to say that movies with budget around that average of 62 million  USD will certainly make over 71.4 million USD in profits or over 6.5 in ratings, no! This just gives an idea of budget to expect it takes to make a successful movie. At best, this figure represent a higher possibility of producing a successful movie if the budget is around this average and the kind of profit you could ***possibly*** make.

# %% [markdown]
#  ### Summary Question 2: Which actors that appeared the most in successful movies in the last 15 years?
#  This question gives insight to who the top and most exprienced actors/actresses are in last 15 years who are likely still active in the industry. I'll create a plot to visualize this, this plot will show a ranking of the top 10 actors/actresses in the last 15 years..

# %%
#creating a dataframe to hold the top 10 actors/actresses in the last 15yrs
last15yrs_topcast = fetch_vcount(last15yrs,'cast',10)
#displaying the rankings 
last15yrs_topcast
# Out:
# Brad Pitt         17
# Adam Sandler      17
# Steve Carell      16
# Cameron Diaz      16
# Ben Stiller       16
# Matt Damon        16
# Johnny Depp       15
# Christian Bale    15
# Anne Hathaway     15
# Mark Wahlberg     15
# dtype: int64

# %%
#creating the plot
ax = last15yrs_topcast.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 10 Cast In The Last 15 Years (2000 - 2015)', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Featuring', fontsize = '14')
#labelling the y axis
plt.ylabel('Actors/Actresses', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# Wow! Brad Pitt appears in the top once more, the man's a legend. However, Adam Sandler also has a tie with Brad Pitt both featuring in 17 successful movies in the last 15 years. Notice how a lot of the top actors/actresses that were in the last plot of all successful movies do not appear here, this could be to possibly due to retirement, or they're no longer in the prime of their career. But a few like Brad Pitt, Cameron Diaz, Johnny Depp and Matt Damon still appear on this ranking... Truly exceptional talents, very commendable.

# %% [markdown]
# ### Summary Question 3: Which actors that appeared the most in successful movies in the last 5 years?
#  This question gives insight to who the top guns in recent times or currently in the industry. I expect to see new talented actors/actresses that are in their prime right now, the new generation of movies stars if I may say. I'll create a plot to visualize this, this plot will show a ranking of the top 10 actors/actresses in the last 5 years...

# %%
#creating a dataframe to hold the top 10 actors/actresses in the last 15yrs
last5yrs_topcast = fetch_vcount(last5yrs,'cast',10)
#displaying the rankings 
last5yrs_topcast
# Out:
# Steve Carell         10
# Anne Hathaway         9
# Bradley Cooper        9
# Tom Hardy             9
# Matt Damon            8
# Jennifer Lawrence     8
# Jonah Hill            8
# Ben Kingsley          8
# Jake Gyllenhaal       8
# Mark Wahlberg         7
# dtype: int64

# %%
#creating the plot
ax = last5yrs_topcast.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 10 Cast In The Last 5 Years (2010 - 2015)', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Featuring', fontsize = '14')
#labelling the y axis
plt.ylabel('Actors/Actresses', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# As expected some of the top artist in the last 15 years no longer appear in this ranking. New talents have surfaced in the industry, and are in the prime of their career such as Anne Hatheway, Bradley Cooper, Top Hardy, Jennifer Lawrence and some others. However, Steve Carell tops this ranking and he also appeared in the last ranking as well as Matt Damon, they would be most likely in still in the prime of their career, not for much longer though I reckon based on the patterb I've observed so far, but that's marely a speculation. Giving credit to where credit's due, Matt Damon appeared in all 3 rankings wow! The man is truly exceptional, I would definately recommend him without batting an eye haha.

# %% [markdown]
# ### Summary Question 4: who are the top 15 directors that directed the most number of succesful movies in the last decade?
#  This question gives insight to who the top and most exprienced directors are in last decade who are likely still active in the industry. I'll create a plot to visualize this, this plot will show a ranking of the top 15  movie directors in the last decade.

# %%
#creating a dataframe to hold the top 15 directors in the last 10yrs
last10yrs_topdirectors = fetch_vcount(last10yrs,'director',15)
#displaying the ranking
last10yrs_topdirectors
# Out:
# Steven Spielberg     7
# Clint Eastwood       7
# Ridley Scott         6
# Christopher Nolan    6
# Francis Lawrence     6
# Tim Burton           6
# Carlos Saldanha      5
# Peter Jackson        5
# Shawn Levy           5
# J.J. Abrams          5
# Quentin Tarantino    5
# Dennis Dugan         5
# Lasse Hallstr̦m     5
# David Fincher        5
# Jon M. Chu           4
# dtype: int64

# %%
#creating the plot
ax = last10yrs_topdirectors.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 15 Directors In The Last Decade (2005 - 2015)', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Directed', fontsize = '14')
#labelling the y axis
plt.ylabel('Directors', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# From the plot we can see the top directors that produced the most number of successful movies in the last decade. wow! Steve Spielberg tops the chart once more, very impressive, followed by him are Clint Eastwood, Ridley Scott, Christopher Nolan, Francis Lawrence and and a few others.

# %% [markdown]
# ### Summary Question 5: what are the top 15 studios that produced  the most number of successful movies in the last decade?

# %% [markdown]
# This question gives insight to which studios or production companies makes the most number of successful movies top in last decade who are likely still very relevant in the industry. I'll create a plot to visualize this, this plot will show a ranking of the top 15 movie studios in the last decade..

# %%
last10yrs_topstudios = fetch_vcount(last10yrs,'production_companies',15)
#displaying the ranking
last10yrs_topstudios
# Out:
# Warner Bros.                              76
# Universal Pictures                        76
# Columbia Pictures                         63
# Paramount Pictures                        57
# Relativity Media                          50
# Twentieth Century Fox Film Corporation    48
# Walt Disney Pictures                      43
# New Line Cinema                           35
# Dune Entertainment                        30
# Legendary Pictures                        25
# Summit Entertainment                      25
# Village Roadshow Pictures                 24
# Metro-Goldwyn-Mayer (MGM)                 22
# DreamWorks SKG                            21
# Fox 2000 Pictures                         20
# dtype: int64

# %%
#creating the plot
ax = last10yrs_topstudios.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 15 Movie Studios In The Last Decade (2005 - 2015)', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Produced', fontsize = '14')
#labelling the y axis
plt.ylabel('Studios/Production Companies', fontsize = '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# There's seem to be a strong rivalry between the Warner Brothers and Universal picture to take the crown as the number 1 movie production company. On the previous top studio chart, we see that Universal Pictures takes the lead by a small margin, and right now they haven't been beaten just yet, as both Universal Pictures and the Warner Brothers produced 76 successful movies.Overall, Universal Pictures takes the crown, but in this decade, Warner Bros leveled up to hold that possition alongside Universal Pictures. There are also new faces we see here  on this ranking, most likely newer studios or older studios that have stepped up their game in recent times. I think it's safe to say the studios ranked here are highly recommendable.

# %% [markdown]
# ### What are the most popular Genres currently?
# Let's see which genres are prominent and produced the most in recent times. I'll take in the last 5 years period. This will give insight to the genres that are in trend right now which our agaency should put effort to be a part of the trend.

# %%
#creating a dataframe to hold the top 10 genres in the last 5yrs
last5yrs_topgenres = fetch_vcount(last5yrs,'genres',10)
#displaying the rankings 
last5yrs_topgenres
# Out:
# Drama              238
# Comedy             162
# Action             144
# Adventure          125
# Thriller           114
# Science Fiction     79
# Romance             79
# Family              71
# Fantasy             60
# Animation           55
# dtype: int64

# %%
#creating the plot
ax = last5yrs_topgenres.plot.barh(fontsize = 15)
#Setting a title
plt.title('Top 10 most produced Genres In The Last 5 Years (2010 - 2015)', fontsize = '20')
# naming the x axis
plt.xlabel('Number of Movies Produced', fontsize = '14')
#labelling the y axis
plt.ylabel('Genres', fontsize= '14')
#seting the plot dimensions
ax.figure.set_size_inches(15, 10)
#shwoing the plot
plt.show()

# %% [markdown]
# Frankly, not much has changed really, but notice how in recent times Animation has finally made it's way into the top 10 charts, this ***could*** be due to the fact that the technology used to make animations have greatly improved and it's being welcomed a lot by the new generation, hence  gaining more prominence in the industry,  Science Fiction has also come up the the chart, Most of the top movies in recent times are based on science fiction, so it is expected to climb up the charts... We can also see other genres that has been in the all time chart, and some are no longer in this ranking, perpharps they are no longer trending like they use to. In any case, Drama is the queen she has always been, holding the crown for decades, pun intended. ;)

# %% [markdown]
# <hr>

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# The conclusions and recommendations I would be making are refrenced from the results from the questions asked earlier, I was able to visualize them as well. Rest assured the conclusions are based on the findings after data exploration.
# After exploring the data, I would summarize and conclude by answering this questions;
#
# **Which directors would you recommend to be hired?**
# It's a large pool of directors to pick from, however I would recommend these directors to increase the chance of producing a sucessful movie; Steven Spielberg, Clint Eastwood, Ridley Scott, Christopher Nolan, Francis Lawrence, Tim Burton, Carlos Saldanha, Peter Jackson, Shawn Levy, J.J. Abrams, Quentin Tarantino, Dennis Dugan, Lasse Hallstr̦m, David Fincher, and Jon M. Chu.
#
# **Which actors/actresswould you recommend to be hired in the cast?**
# I would say it depends on what kind of actors is needed, is it actors that are top shots in the industry right now and in the prime of their careers, or you want the housholdnames and more exprienced top actors?
# For the first, I'd recommend any of these actors; Steve Carell, Anne Hathaway, Bradley Cooper, Tom Hardy, Matt Damon, Jennifer Lawrence, Jonah Hill, Ben Kingsley, Jake Gyllenhaal, and Mark Wahlberg.
# If its the latter I'll recommend these actors; Brad Pitt, Adam Sandler, Steve Carell, Cameron Diaz, Ben Stiller, Matt Damon, Johnny Depp, Christian Bale, Anne Hathaway, and Mark Wahlberg.
# In Summary any of those actors would be recommendable to make a successful movie.
#
#
#
# **Which directors would you recommend to be hired?**
# It's a large pool of directors to pick from, however I would recommend any of these directors to increase the chance of producing a sucessful movie; Steven Spielberg, Clint Eastwood, Ridley Scott, Christopher Nolan, Francis Lawrence, Tim Burton, Carlos Saldanha, Peter Jackson, Shawn Levy, J.J. Abrams, Quentin Tarantino, Dennis Dugan, Lasse Hallstr̦m, David Fincher, and Jon M. Chu.
#
# **Which actors/actresswould you recommend to be hired in the cast?**
# I would say it depends on what kind of actors is needed, is it actors that are top shots in the industry right now and in the prime of their careers, or you want the housholdnames and more exprienced top actors?
# For the first, I'd recommend any of these actors; Steve Carell, Anne Hathaway, Bradley Cooper, Tom Hardy, Matt Damon, Jennifer Lawrence, Jonah Hill, Ben Kingsley, Jake Gyllenhaal, and Mark Wahlberg.
# If its the latter I'll recommend any of these actors; Brad Pitt, Adam Sandler, Steve Carell, Cameron Diaz, Ben Stiller, Matt Damon, Johnny Depp, Christian Bale, Anne Hathaway, and Mark Wahlberg.
# In Summary any of those actors would be recommendable to make a successful movie.
#
# **Which Studios would you recommend the agency pathnership and strive to build ties with?**
# In order to follow the money, I would recommend the agency put effort into pathnering and building ties to work closey with these production  companies/studios; Warner Bros, Universal Pictures, Columbia Pictures, Paramount Pictures, Relativity Media, Twentieth Century Fox Film Corporation, Walt Disney Pictures, New Line Cinema, Dune Entertainment, Legendary Pictures, Summit Entertainment, Village Roadshow Pictures, Metro-Goldwyn-Mayer, DreamWorks SKG, and Fox 2000 Pictures.
#
# **Which genres should the Agency put more Focus on?**
# I would recommend that the agency put more efforts in working with industry professionals or studios that can contribute to the production of movies in any or all of these genres; Drama, Comedy, Action, Adventure, Thriller, Science Fiction, Romance, Family, Fantasy, and Animation
#
#
# By doing all this, We can Increase the probability of being part in the production profitable movies and/or movies with high ratings, of which both criteria counts as success. Obviously there are other factors that influnce the success of a movie and I fully acknowlege that. The rationale, is to be one of the contributors to successful movies, this means more revenue to the agency when the movie is highly profitable, and if the movie has high ratings it promotes the agency's goodwill which inturn could translate to more revenue. ;)

# %% [markdown]
# **LIMITATIONS**

# %% [markdown]
# The most prevailing limitation to note is that this analysis comes with ***no guaranty*** that by following the findings we would ***certaintly*** achieve expected. This analysis is quite limited as it cannot account for many factors that influence the success of a movie such as geopolitcical, economic, enviromental and may other factors that can influence how a movie performs in the box office. If the very basis of our parameters(i.e profit and ratings) of limited, then certainly ***I can not claim that any conclusion or recommendations are 100% reliable nor 100% accurate***. I am merely trying to increase our chances of being part of a successful movie based on results from my data anylsis.

# %% [markdown]
# THE END!
